# %%
import pandas as pd

# %%
file_path=r"C:\Users\ggmik\Downloads\car_insurance.csv"
df=pd.read_csv(file_path)

# %%
df=pd.read_csv(file_path)

# %%
df
# Out:
#       policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0       ID00001       0.515874         5.0                   45           C1
# 1       ID00002       0.672619         2.0                   26           C2
# 2       ID00003       0.841110         2.0                   27           C3
# 3       ID00004       0.900277        11.0                   30           C4
# 4       ID00005       0.596403        11.0                   45           C5
# ...         ...            ...         ...                  ...          ...
# 58573   ID58588       0.355089        13.0                   45           C8
# 58574   ID58589       1.199642         2.0                   36          C14
# 58575   ID58590       1.162273         5.0                   32           C5
# 58576   ID58591       1.236307        14.0                   39           C8
# 58577   ID58592       0.124429         2.0                   31           C8
#
# ...

# %%
##3. Show the top five rows and also show the top 15 rows
df.head()
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874         5.0                   45           C1
# 1   ID00002       0.672619         2.0                   26           C2
# 2   ID00003       0.841110         2.0                   27           C3
# 3   ID00004       0.900277        11.0                   30           C4
# 4   ID00005       0.596403        11.0                   45           C5
#
#    population_density fuel_type  max_power transmission_type  gross_weight  \
# 0                4990       CNG         40            Manual          1185
# 1               27003       CNG         40            Manual          1185
# 2                4076       CNG         40            Manual          1185
# 3               21622    Petrol         88         Automatic          1335
# 4               34738    Petrol         67         Automatic          1155
#
#    ncap_rating
# 0            0
# 1            0
# 2            0
# ...

# %%
df.head(15)
# Out:
#    policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0    ID00001       0.515874         5.0                   45           C1
# 1    ID00002       0.672619         2.0                   26           C2
# 2    ID00003       0.841110         2.0                   27           C3
# 3    ID00004       0.900277        11.0                   30           C4
# 4    ID00005       0.596403        11.0                   45           C5
# 5    ID00006       1.018709         7.0                   36           C6
# 6    ID00007       0.097992        16.0                   28           C7
# 7    ID00008       0.509085        14.0                   30           C8
# 8    ID00009       0.282394         7.0                   21           C7
# 9    ID00010       0.566255         4.0                   31           C9
# 10   ID00011       0.951416         1.0                   42           C5
# 11   ID00012       0.083180        12.0                   21           C3
# ...

# %%
###4. Show the bottom five rows
df.tail()
# Out:
#       policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 58573   ID58588       0.355089        13.0                   45           C8
# 58574   ID58589       1.199642         2.0                   36          C14
# 58575   ID58590       1.162273         5.0                   32           C5
# 58576   ID58591       1.236307        14.0                   39           C8
# 58577   ID58592       0.124429         2.0                   31           C8
#
#        population_density fuel_type  max_power transmission_type  \
# 58573                8794    Petrol         67         Automatic
# 58574                7788       CNG         40            Manual
# 58575               34738       CNG         40            Manual
# 58576                8794    Petrol         88            Manual
# 58577                8794    Diesel        113         Automatic
#
#        gross_weight  ncap_rating
# 58573          1155            2
# 58574          1185            0
# ...

# %%
###5. What is the shape of the dataframe?
df.shape
# Out:
# (58578, 11)

# %%
##What are the column data types?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58578 entries, 0 to 58577
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   policy_id            58578 non-null  object
#  1   policy_tenure        58578 non-null  float64
#  2   age_of_car           58578 non-null  float64
#  3   age_of_policyholder  58578 non-null  int64
#  4   area_cluster         58578 non-null  object
#  5   population_density   58578 non-null  int64
#  6   fuel_type            58578 non-null  object
#  7   max_power            58578 non-null  int64
#  8   transmission_type    58578 non-null  object
#  9   gross_weight         58578 non-null  int64
#  10  ncap_rating          58578 non-null  int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 4.9+ MB

# %%
##7. How old are the oldest cars in the dataset?
df['age_of_car'].max()
# Out:
# 39.0

# %%
##What is the youngest age of the policyholders?
df['age_of_policyholder'].min()
# Out:
# 20

# %%
##Which fuel types are there, how many are there?
df['fuel_type'].unique()
len(df['ncap_rating'].unique())
# Out:
# 5

# %%
###Rename column gross_weight to car_weight
df.rename(columns = {'gross_weight':'car_weight'}, inplace = True)

# %%
##Create a new column dividing column power with column car_weight. Name it as power_per_kg
df['power_per_kg']=df['max_power']/df['car_weight']
df.head()
df['power_per_kg'].max()
# Out:
# 0.0922930542340628

# %%
###16. What is the average age of car
df['age_of_car'].mean()
# Out:
# 6.928829936153504

# %%
##Display the last 20 rows of the dataset
df.tail()
# Out:
#       policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 58573   ID58588       0.355089        13.0                   45           C8
# 58574   ID58589       1.199642         2.0                   36          C14
# 58575   ID58590       1.162273         5.0                   32           C5
# 58576   ID58591       1.236307        14.0                   39           C8
# 58577   ID58592       0.124429         2.0                   31           C8
#
#        population_density fuel_type  max_power transmission_type  car_weight  \
# 58573                8794    Petrol         67         Automatic        1155
# 58574                7788       CNG         40            Manual        1185
# 58575               34738       CNG         40            Manual        1185
# 58576                8794    Petrol         88            Manual        1335
# 58577                8794    Diesel        113         Automatic        1720
#
#        ncap_rating
# 58573            2
# ...

# %%
###Change the type of ncap_rating variable to string
df['ncap_rating']=df['ncap_rating'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58578 entries, 0 to 58577
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   policy_id            58578 non-null  object
#  1   policy_tenure        58578 non-null  float64
#  2   age_of_car           58578 non-null  float64
#  3   age_of_policyholder  58578 non-null  int64
#  4   area_cluster         58578 non-null  object
#  5   population_density   58578 non-null  int64
#  6   fuel_type            58578 non-null  object
#  7   max_power            58578 non-null  int64
#  8   transmission_type    58578 non-null  object
#  9   car_weight           58578 non-null  int64
#  10  ncap_rating          58578 non-null  object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 4.9+ MB

# %%
###Create a 'policy_id_length' column that indicates the length of the 'policy_id' string.
df['policy_id_length']=df['policy_id'].astype(str).apply(len)

# %%
###20. Find the total number of cars with an ncap rating of 5.
df['ncap_rating'].value_counts()['5']
# Out:
# 1961

# %%
###How many different transmission types are there?
df['transmission_type'].unique()
len(df['transmission_type'].unique())
# Out:
# 2

# %%
##Find how many policies belong to each transmission type.
df['transmission_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
