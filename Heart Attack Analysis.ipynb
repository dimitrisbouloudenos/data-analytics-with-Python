# %%
import pandas as pd
file_path=r"C:\Users\ggmik\Downloads\archive (12)\Medicaldataset.csv"

# %%
df=pd.read_csv(file_path)

# %%
df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
##null
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %%
df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
##Gender Man and Result positive
df[(df['Gender']==1) & (df['Result']=='positive')]
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 1      21       1          94                       98
# 3      64       1          70                      120
# 7      63       1          60                      214
# 12     64       1          60                      199
# 15     61       1          81                      118
# ...   ...     ...         ...                      ...
# 1311   85       1         112                      115
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar   CK-MB  Troponin    Result
# 1                           46        296.0    6.75     1.060  positive
# 3                           55        270.0   13.87     0.122  positive
# 7                           82         87.0  300.00     2.370  positive
# ...

# %%
##Age over 60
df[df['Age']>60]
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 3      64       1          70                      120
# 7      63       1          60                      214
# 9      67       1          61                      160
# 11     63       0          60                      150
# ...   ...     ...         ...                      ...
# 1299   62       1          90                      136
# 1310   70       0          80                      135
# 1311   85       1         112                      115
# 1313   86       0          40                      179
# 1315   66       1          84                      125
#
#       Diastolic blood pressure  Blood sugar   CK-MB  Troponin    Result
# 0                           83        160.0    1.80     0.012  negative
# 3                           55        270.0   13.87     0.122  positive
# 7                           82         87.0  300.00     2.370  positive
# ...

# %%
df(df['Heart rate'>100]).value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df(df['Heart rate'>100]).value_counts()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
##How many patient have heart rate > 100
(df['Heart rate']>100).sum()
# Out:
# 82

# %%
df['Result'].value_counts()
# Out:
# positive    810
# negative    509
# Name: Result, dtype: int64

# %%
##Patient with age between 40 and 60
df[(df['Age']>40) & (df['Age']<60)]
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 2      55       1          64                      160
# 4      55       1          64                      112
# 5      58       0          61                      112
# 8      44       0          60                      154
# 10     44       0          60                      166
# ...   ...     ...         ...                      ...
# 1312   48       1          84                      118
# 1314   44       1          94                      122
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 2                           77        270.0   1.99     0.003  negative
# 4                           65        300.0   1.08     0.003  negative
# 5                           58         87.0   1.83     0.004  negative
# ...

# %%
df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
##Average Heart Rate by Result
df.groupby('Result')['Heart rate'].mean()
# Out:
# Result
# negative    77.886051
# positive    78.619753
# Name: Heart rate, dtype: float64

# %%
##Average Blood sugar by Result
df.groupby('Result')['Blood sugar'].mean()
# Out:
# Result
# negative    149.757760
# positive    144.671605
# Name: Blood sugar, dtype: float64

# %%
df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
## Function to create a new column to find risk of Blood Sugar
def Sugar(x):
    if x>200:
        return 'High'
    else:
        return 'Low'

# %%
df['Sugar_Risk']=df['Blood sugar'].apply(Sugar)

# %%
df['Sugar_Risk']
# Out:
# 0        Low
# 1       High
# 2       High
# 3       High
# 4       High
#         ...
# 1314    High
# 1315     Low
# 1316     Low
# 1317    High
# 1318     Low
# Name: Sugar_Risk, Length: 1319, dtype: object

# %%
df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result  \
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
### Categorize Heart Rate to low,normal,high
def Heart_Rate(x):
    if x>100:
        return 'High'
    elif x>60 and x<100:
        return 'Medium'
    else:
        return 'Low'

# %%
df['Categorize_Heart_Rate']=df['Heart rate'].apply(Heart_Rate)

# %%
df['Categorize_Heart_Rate'].value_counts()
# Out:
# Medium    1022
# Low        215
# High        82
# Name: Categorize_Heart_Rate, dtype: int64

# %%
###Visualize Result
df['Categorize_Heart_Rate'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result  \
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=df,x='Result')
plt.xlabel('Result')
plt.ylabel('Count')
plt.title('Result Count')
# Out:
# Text(0.5, 1.0, 'Result Count')

# %%
##Heart Rate distribition
df['Heart rate'].hist(bins=5)
# Out:
# <Axes: >
